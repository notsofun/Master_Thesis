# %%
import pandas as pd

df = pd.read_csv('all_search_posts.csv')
df.info()
print(len(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23630 entries, 0 to 23629
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         23630 non-null  object
#  1   floor         23630 non-null  int64
#  2   author        20846 non-null  object
#  3   time          23630 non-null  object
#  4   main_content  21568 non-null  object
#  5   lzl_replies   0 non-null      float64
#  6   link          23630 non-null  object
#  7   keyword       23630 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.4+ MB
# 23630
