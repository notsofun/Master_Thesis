# %%
from bertopic import BERTopic

# 加载你刚才保存的模型
topic_model = BERTopic.load(r"topic_modeling_results\sixth\models\bertopic_model")

# 获取话题详情表
info = topic_model.get_topic_info()

print(info)
# Out:
# 2026-03-31 12:30:27,660 - BERTopic - WARNING: You are loading a BERTopic model without explicitly defining an embedding model. If you want to also load in an embedding model, make sure to use `BERTopic.load(my_model, embedding_model=my_embedding_model)`.
#     Topic  Count                             Name  \
# 0      -1   2530                   -1_教会内的包容与变革挑战
# 1       0    499                 0_日本政教分离与统治集团的腐败
# 2       1    312                  1_基督教徒与特朗普的政治关系
# 3       2    208                       2_女性与神职的关系
# 4       3    149            3_教会中的LGBTQ议题与年轻人的疏离感
# 5       4    143                        4_宗教、性与暴力
# 6       5    138                5_天主教和路德宗的圣餐与礼仪争议
# 7       6    122                  6_教会性虐待受害者与救助机制
# 8       7    119                   7_宗教信仰与自然灾难的辩论
# 9       8    117                    8_生命与女性自主权的辩论
# 10      9    103                     9_耶稣的神人关系与教导
# 11     10     93                   10_圣经与信仰的冲突与反思
# 12     11     81  11_2017年巴基斯坦基督教徒与穆斯林暴力事件及媒体报道偏见
# ...
